# %% [markdown]
# ### Mounting Drive

# %%
import os
import sys

PROJECT_NAME = 'practice-ds-sales-data-1'

try:

    from google.colab import drive
    drive.mount('/content/drive')
    
    PROJECT_ROOT = f'/content/drive/My Drive/Data Science/Personal/{PROJECT_NAME}'

    print("Running in Google Colab.")

except:

    PROJECT_ROOT = rf'H:\My Drive\Data Science\Personal/{PROJECT_NAME}'

    print("Running in local environment.")

# Move to project root
os.chdir(PROJECT_ROOT)

print("Current working directory:", os.getcwd())

# Add project root to Python path
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)
# Out:
# Running in local environment.
# Current working directory: H:\My Drive\Data Science\Personal\practice-ds-sales-data-1

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd

# %% [markdown]
# ### Task 1: Merge the 12 months of sales data into a single csv file

# %%
files = []

for file in os.listdir("./dataset/sales-data"):
    files.append(file)

all_months_data = pd.DataFrame()

for file in files:
    path = "./dataset/sales-data/" + file
    df = pd.read_csv(path)
    all_months_data = pd.concat([all_months_data, df])

all_months_data.sample(10)
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 5347    283907  Bose SoundSport Headphones                1      99.99
# 7325    216898      34in Ultrawide Monitor                1     379.99
# 13580   207012    Apple Airpods Headphones                1        150
# 12657   206123      AAA Batteries (4-pack)                1       2.99
# 4956    155226            27in FHD Monitor                1     149.99
# 2622    212413            27in FHD Monitor                1     149.99
# 6916    265960            Wired Headphones                1      11.99
# 5883    199682            Wired Headphones                1      11.99
# 3392    197314        USB-C Charging Cable                1      11.95
# 5563    199378            Wired Headphones                1      11.99
#
#            Order Date                        Purchase Address
# 5347   11/27/19 08:15          157 River St, Dallas, TX 75001
# 7325   06/02/19 05:21  186 Chestnut St, Los Angeles, CA 90001
# 13580  05/19/19 08:03    350 13th St, San Francisco, CA 94016
# 12657  05/05/19 15:30        675 Dogwood St, Austin, TX 73301
# 4956   02/11/19 19:41  620 Forest St, San Francisco, CA 94016
# 2622   06/15/19 11:48    481 Hill St, San Francisco, CA 94016
# 6916   10/27/19 10:54        837 Center St, Seattle, WA 98101
# 5883   05/16/19 12:39          871 Adams St, Boston, MA 02215
# 3392   05/16/19 22:00   944 Johnson St, Los Angeles, CA 90001
# 5563   05/11/19 23:25       375 Jackson St, Seattle, WA 98101
